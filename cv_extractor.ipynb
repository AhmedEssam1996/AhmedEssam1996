# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedEssam1996/AhmedEssam1996/blob/main/cv_extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

with zipfile.ZipFile("cv.zip", "r") as zip_ref:
    zip_ref.extractall("project")

# %%
# %cd /content/project/cv-portfolio
# Out:
# /content/project/cv-portfolio

# %%
# !pip install -r requirements.txt

# %%
# !pip uninstall -y transformers peft sentence-transformers accelerate
# Out:
# Found existing installation: transformers 4.41.2
# Uninstalling transformers-4.41.2:
#   Successfully uninstalled transformers-4.41.2
# Found existing installation: peft 0.10.0
# Uninstalling peft-0.10.0:
#   Successfully uninstalled peft-0.10.0
# Found existing installation: sentence-transformers 2.7.0
# Uninstalling sentence-transformers-2.7.0:
#   Successfully uninstalled sentence-transformers-2.7.0
# Found existing installation: accelerate 0.30.1
# Uninstalling accelerate-0.30.1:
#   Successfully uninstalled accelerate-0.30.1

# %%
# !pip install transformers==4.41.2
# !pip install peft==0.10.0
# !pip install sentence-transformers==2.7.0
# !pip install accelerate==0.30.1
# Out:
# ...
#   Using cached transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
# ...
# Using cached transformers-4.41.2-py3-none-any.whl (9.1 MB)
# ...
#   Using cached peft-0.10.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# ...
# Using cached peft-0.10.0-py3-none-any.whl (199 kB)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# ...
#   Using cached sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# ...
#   Using cached accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached accelerate-0.30.1-py3-none-any.whl (302 kB)
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.13.0
#     Uninstalling accelerate-1.13.0:
#       Successfully uninstalled accelerate-1.13.0
# ...

# %%
# !python main.py
# Out:
# --- Processing Local CV: /content/project/cv.pdf ---
# Extracting text from PDF: /content/project/cv.pdf
# Extracted 4435 characters from PDF.
#
# ...
# DEBUG: DETECTED SECTIONS CONTENT
# ...
#
# >>>> HEADER <<<<
# 1
#
# Ahmed Essam
# ...
# - Education
#  bachelor’s degree in biomedical
# engineering – HTI University
#
# >>>> SUMMARY <<<<
# AI Developer and Machine Learning Engineer with
#
# >>>> SKILLS <<<<
# in AI-driven data pipelines, predictive modelling,
# and end-to-end ML deployment. Skilled in building
# scalable pipelines that accelerate model training and
# ...
# - Solid understanding of software analysis and development cycles.
# - Strong in problem-solving, debugging, and performance optimization.
# - Skilled in deploying and monitoring machine learning models in production.
#
# >>>> EXPERIENCE <<<<
# Present
# Company name- Zone Trading
# Company – KSA
# ...
#
#
# Other
#
# >>>> PROJECTS <<<<
# Taxi Price Regression Model
#  Developed a regression model to predict taxi fares.
# ...
